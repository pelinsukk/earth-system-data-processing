# %% [markdown]
# # HW2 – Mini run demonstration
#
# This notebook documents a minimal interaction with the HW2 daily processing
# pipeline to demonstrate how it is executed and configured.

# %%
# !python ../scripts/daily_processing.py --help

# %% [markdown]
# The help output confirms that the processing script is executable and that
# all required CLI arguments are correctly defined.
